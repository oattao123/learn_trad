# %%
import ccxt
import pandas as pd

# %%
print(ccxt.exchanges)
# Out:
# ['ace', 'alpaca', 'ascendex', 'bequant', 'bigone', 'binance', 'binancecoinm', 'binanceus', 'binanceusdm', 'bingx', 'bit2c', 'bitbank', 'bitbay', 'bitbns', 'bitcoincom', 'bitfinex', 'bitfinex2', 'bitflyer', 'bitget', 'bithumb', 'bitmart', 'bitmex', 'bitopro', 'bitpanda', 'bitrue', 'bitso', 'bitstamp', 'bitteam', 'bitvavo', 'bl3p', 'blockchaincom', 'blofin', 'btcalpha', 'btcbox', 'btcmarkets', 'btcturk', 'bybit', 'cex', 'coinbase', 'coinbaseadvanced', 'coinbaseexchange', 'coinbaseinternational', 'coincheck', 'coinex', 'coinlist', 'coinmate', 'coinmetro', 'coinone', 'coinsph', 'coinspot', 'cryptocom', 'currencycom', 'delta', 'deribit', 'digifinex', 'exmo', 'fmfwio', 'gate', 'gateio', 'gemini', 'hitbtc', 'hitbtc3', 'hollaex', 'htx', 'huobi', 'huobijp', 'hyperliquid', 'idex', 'independentreserve', 'indodax', 'kraken', 'krakenfutures', 'kucoin', 'kucoinfutures', 'kuna', 'latoken', 'lbank', 'luno', 'lykke', 'mercado', 'mexc', 'ndax', 'novadax', 'oceanex', 'okcoin', 'okx', 'onetrading', 'oxfun', 'p2b', 'paymium', 'phemex', 'poloniex', 'poloniexfutures', 'probit', 'timex', 'tokocrypto', 'tradeogre', 'upbit', 'wavesexchange', 'wazirx', 'whitebit', 'woo', 'woofipro', 'xt', 'yobit', 'zaif', 'zonda']

# %%
getattr(ccxt, 'binance')()
# Out:
# ccxt.binance()

# %%
binance = ccxt.binance()

# %%
pd.DataFrame(binance.fetchOHLCV('BTC/USDT', limit=10))
# Out:
#                0         1         2         3         4         5
# 0  1718885340000  66285.70  66289.58  66224.96  66232.19  13.98947
# 1  1718885400000  66232.20  66245.35  66224.96  66245.35  15.94285
# 2  1718885460000  66245.35  66300.50  66245.35  66293.97  31.32051
# 3  1718885520000  66293.96  66293.97  66218.45  66223.84  19.13404
# 4  1718885580000  66223.84  66243.87  66157.56  66157.56  28.84192
# 5  1718885640000  66157.56  66170.00  66109.10  66109.11  22.13348
# 6  1718885700000  66109.10  66125.99  66020.00  66024.55  56.02596
# 7  1718885760000  66024.64  66108.00  66000.00  66108.00  38.48170
# 8  1718885820000  66107.99  66140.00  66060.00  66065.02  27.54521
# 9  1718885880000  66065.02  66082.00  66062.80  66062.80  16.36087

# %%
prices = []
fails = []

for exchange in ccxt.exchanges:
    try:
        prices.append(getprices(exchange,'BTC/USDT'))
        print('prices successfully pulled for '+exchange)
    except:
        fails.append(exchange)
        print('price pull fail for'+exchange)
# Out:
# price pull fail forace
# price pull fail foralpaca
# price pull fail forascendex
# price pull fail forbequant
# price pull fail forbigone
# price pull fail forbinance
# price pull fail forbinancecoinm
# price pull fail forbinanceus
# price pull fail forbinanceusdm
# price pull fail forbingx
# price pull fail forbit2c
# price pull fail forbitbank
# price pull fail forbitbay
# price pull fail forbitbns
# price pull fail forbitcoincom
# price pull fail forbitfinex
# price pull fail forbitfinex2
# price pull fail forbitflyer
# price pull fail forbitget
# price pull fail forbithumb
# price pull fail forbitmart
# price pull fail forbitmex
# price pull fail forbitopro
# price pull fail forbitpanda
# price pull fail forbitrue
# price pull fail forbitso
# price pull fail forbitstamp
# price pull fail forbitteam
# price pull fail forbitvavo
# price pull fail forbl3p
# price pull fail forblockchaincom
# price pull fail forblofin
# price pull fail forbtcalpha
# price pull fail forbtcbox
# price pull fail forbtcmarkets
# price pull fail forbtcturk
# price pull fail forbybit
# price pull fail forcex
# price pull fail forcoinbase
# price pull fail forcoinbaseadvanced
# price pull fail forcoinbaseexchange
# price pull fail forcoinbaseinternational
# price pull fail forcoincheck
# price pull fail forcoinex
# price pull fail forcoinlist
# price pull fail forcoinmate
# price pull fail forcoinmetro
# price pull fail forcoinone
# price pull fail forcoinsph
# price pull fail forcoinspot
# price pull fail forcryptocom
# price pull fail forcurrencycom
# price pull fail fordelta
# price pull fail forderibit
# price pull fail fordigifinex
# price pull fail forexmo
# price pull fail forfmfwio
# price pull fail forgate
# price pull fail forgateio
# price pull fail forgemini
# price pull fail forhitbtc
# price pull fail forhitbtc3
# price pull fail forhollaex
# price pull fail forhtx
# price pull fail forhuobi
# price pull fail forhuobijp
# price pull fail forhyperliquid
# price pull fail foridex
# price pull fail forindependentreserve
# price pull fail forindodax
# price pull fail forkraken
# price pull fail forkrakenfutures
# price pull fail forkucoin
# price pull fail forkucoinfutures
# price pull fail forkuna
# price pull fail forlatoken
# price pull fail forlbank
# price pull fail forluno
# price pull fail forlykke
# price pull fail formercado
# price pull fail formexc
# price pull fail forndax
# price pull fail fornovadax
# price pull fail foroceanex
# price pull fail forokcoin
# price pull fail forokx
# price pull fail foronetrading
# price pull fail foroxfun
# price pull fail forp2b
# price pull fail forpaymium
# price pull fail forphemex
# price pull fail forpoloniex
# price pull fail forpoloniexfutures
# price pull fail forprobit
# price pull fail fortimex
# price pull fail fortokocrypto
# price pull fail fortradeogre
# price pull fail forupbit
# price pull fail forwavesexchange
# price pull fail forwazirx
# price pull fail forwhitebit
# price pull fail forwoo
# price pull fail forwoofipro
# price pull fail forxt
# price pull fail foryobit
# price pull fail forzaif
# price pull fail forzonda

# %%
def getprice(exchange, symbol):
    inst = getattr(ccxt, exchange)()
    df = pd.DataFrame(inst.fetchOHLCV(symbol,limit=60))
    df.columns = ['Time','Open','High','Low','Close','Volume']
    df.set_index('Time',inplace=True)
    df.index = pd.to_datetime(df.index,unit='ms')
    df = df.astype(float)
    return df

# %%
getprice('binance','BTC/USDT')
# Out:
#                          Open      High       Low     Close    Volume
# Time
# 2024-06-20 11:19:00  66378.77  66388.00  66351.32  66354.04  26.36781
# 2024-06-20 11:20:00  66354.03  66354.05  66321.76  66346.01  24.04485
# 2024-06-20 11:21:00  66346.02  66350.00  66331.90  66342.87   7.84247
# 2024-06-20 11:22:00  66342.87  66344.00  66312.68  66312.68  12.76434
# 2024-06-20 11:23:00  66312.69  66319.76  66308.68  66315.15  21.80857
# 2024-06-20 11:24:00  66315.16  66315.16  66293.50  66299.98  46.21159
# 2024-06-20 11:25:00  66299.98  66354.82  66299.98  66354.82  14.76989
# 2024-06-20 11:26:00  66354.81  66404.88  66354.81  66404.88  16.59512
# 2024-06-20 11:27:00  66404.88  66430.76  66404.87  66420.70  14.77209
# 2024-06-20 11:28:00  66420.69  66420.70  66402.01  66402.02   9.84635
# 2024-06-20 11:29:00  66402.01  66416.82  66395.81  66416.81   9.35618
# 2024-06-20 11:30:00  66416.82  66468.00  66416.81  66466.26  27.95287
# 2024-06-20 11:31:00  66466.25  66482.94  66444.90  66482.94  33.94522
# 2024-06-20 11:32:00  66482.93  66482.94  66400.00  66400.01  22.22613
# 2024-06-20 11:33:00  66400.00  66400.01  66320.01  66320.01  28.01016
# 2024-06-20 11:34:00  66320.02  66358.00  66320.01  66352.12  14.01693
# 2024-06-20 11:35:00  66352.13  66363.99  66300.03  66314.00  41.11921
# 2024-06-20 11:36:00  66314.00  66321.56  66300.00  66300.02  11.68682
